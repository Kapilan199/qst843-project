# %% [markdown]
# # Cleaning Dataset
#
# The goal of this notebook is to clean two datasets — review and meta — to prepare them for further analysis.
# We removed fields that are not useful for exploratory data analysis (EDA) or subsequent modeling, and standardized data types and formats to make analysis easier.
#
# ### Dataset Files
# * Review dataset
# * Meta dataset (product information)
#
# ### Remarks
# * Each dataset is divided by main category. In this notebook, we demonstrate our cleaning logic using the “All_Beauty” category.
# * We observed that schema structures and list formats differ across categories. Therefore, we enforced consistent field names and ordering at the end of the cleaning process to ensure standardization.

# %%
bucket = spark._jsc.hadoopConfiguration().get("fs.gs.system.bucket")

# You can redirect the bucket directory to where you stored your datasets!
data = "gs://" + bucket + "/Datasets/"
print(data)
# Out:
# gs://qst843-spark_phs/Datasets/

# %%
# Load Review Data
df = spark.read.json(data + "All_Beauty.jsonl")
df.printSchema()
# Out:
# [Stage 1:=======================================>                   (2 + 1) / 3]
# root
#  |-- asin: string (nullable = true)
#  |-- helpful_vote: long (nullable = true)
#  |-- images: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- attachment_type: string (nullable = true)
#  |    |    |-- large_image_url: string (nullable = true)
#  |    |    |-- medium_image_url: string (nullable = true)
#  |    |    |-- small_image_url: string (nullable = true)
#  |-- parent_asin: string (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- text: string (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- title: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- verified_purchase: boolean (nullable = true)

# %%
# Before Cleaning (Review)
df.printSchema()
df.show(10)
# Out:
# root
#  |-- asin: string (nullable = true)
#  |-- helpful_vote: long (nullable = true)
#  |-- images: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- attachment_type: string (nullable = true)
#  |    |    |-- large_image_url: string (nullable = true)
#  |    |    |-- medium_image_url: string (nullable = true)
#  |    |    |-- small_image_url: string (nullable = true)
#  |-- parent_asin: string (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- text: string (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- title: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- verified_purchase: boolean (nullable = true)
# [Stage 3:>                                                          (0 + 1) / 1]
# +----------+------------+--------------------+-----------+------+--------------------+-------------+--------------------+--------------------+-----------------+
# |      asin|helpful_vote|              images|parent_asin|rating|                text|    timestamp|               title|             user_id|verified_purchase|
# +----------+------------+--------------------+-----------+------+--------------------+-------------+--------------------+--------------------+-----------------+
# |B00YQ6X8EO|           0|                  []| B00YQ6X8EO|   5.0|This spray is rea...|1588687728923|Such a lovely sce...|AGKHLEW2SOWHNMFQI...|             true|
# |B081TJ8YS3|           1|                  []| B081TJ8YS3|   4.0|This product does...|1588615855070|Works great but s...|AGKHLEW2SOWHNMFQI...|             true|
# |B07PNNCSP9|           2|                  []| B097R46CSY|   5.0|Smells good, feel...|1589665266052|                Yes!|AE74DYR3QUGVPZJ3P...|             true|
# |B09JS339BZ|           0|                  []| B09JS339BZ|   1.0|      Felt synthetic|1643393630220|   Synthetic feeling|AFQLNQNQYFWQZPJQZ...|             true|
# |B08BZ63GMJ|           0|                  []| B08BZ63GMJ|   5.0|             Love it|1609322563534|                  A+|AFQLNQNQYFWQZPJQZ...|             true|
# |B00R8DXL44|           0|[{IMAGE, https://...| B00R8DXL44|   4.0|The polish was qu...|1598567408138|        Pretty Color|AGMJ3EMDVL6OWBJF7...|             true|
# |B099DRHW5V|           0|                  []| B099DRHW5V|   5.0|Great for many ta...|1631885519443|               Handy|AHREXOGQPZDA6354M...|             true|
# |B088SZDGXG|           0|[{IMAGE, https://...| B08BBQ29N5|   3.0|These were lightw...|1634275259292|                 Meh|AEYORY2AVPMCPDV57...|             true|
# |B08P2DZB4X|           0|                  []| B08P2DZB4X|   5.0|This is perfect f...|1627391044559|Great for at home...|AFSKPY37N3C43SOI5...|            false|
# |B086QY6T7N|           0|                  []| B086QY6T7N|   5.0|I get Keratin tre...|1626614511145|Nice shampoo for ...|AFSKPY37N3C43SOI5...|            false|
# +----------+------------+--------------------+-----------+------+--------------------+-------------+--------------------+--------------------+-----------------+
# only showing top 10 rows

# %%
# Review dataset cleaning
from pyspark.sql.functions import col, when, length, regexp_replace, trim, to_timestamp, size, coalesce, lit, date_format, lower

## Drop asin
df = df.drop("asin")

## New Column "image_exist" to flag whether review contains image or not
df = df.withColumn(
    "review_image",
    (coalesce(size(col("images")), lit(0)) > 0)
)

## Drop image
df = df.drop("images")

## Type re-organize
df = (df
      .withColumn("helpful_vote", col("helpful_vote").cast("int"))
      .withColumn("rating", col("rating").cast("int"))
      .withColumn("verified_purchase", col("verified_purchase").cast("boolean"))
)

## timestamp(ms) → timestamp(sec) -> yyyy-MM-dd HH:mm:ss format
df = df.withColumn("timestamp", to_timestamp((col("timestamp")/1000).cast("double")))
df = df.withColumn("timestamp", date_format(col("timestamp"), "yyyy-MM-dd HH:mm:ss"))

## String text clean(trim)
df = (df
      .withColumn("review_title", trim(regexp_replace(col("title"), r"\s+", " ")))
      .withColumn("review_text",  trim(regexp_replace(col("text"),  r"\s+", " ")))
)
df = df.drop("title", "text")

## Rating check(1-5)
df = df.where((col("rating") >= 1.0) & (col("rating") <= 5.0))

## Drop duplicates
df = df.dropDuplicates(["user_id", "parent_asin", "timestamp", "review_title"])



## Column order reconstruct
final_cols = [
    "user_id",
    "parent_asin",
    "timestamp",
    "rating",
    "review_title",
    "review_text",
    "helpful_vote",
    "verified_purchase",
    "review_image",
]
df = df.select(*final_cols)

# %%
# After Cleaning (Review)
df.printSchema()
df.show(10)
# Out:
# root
#  |-- user_id: string (nullable = true)
#  |-- parent_asin: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- rating: integer (nullable = true)
#  |-- review_title: string (nullable = true)
#  |-- review_text: string (nullable = true)
#  |-- helpful_vote: integer (nullable = true)
#  |-- verified_purchase: boolean (nullable = true)
#  |-- review_image: boolean (nullable = false)
# [Stage 6:>                                                          (0 + 1) / 1]
# +--------------------+-----------+-------------------+------+--------------------+--------------------+------------+-----------------+------------+
# |             user_id|parent_asin|          timestamp|rating|        review_title|         review_text|helpful_vote|verified_purchase|review_image|
# +--------------------+-----------+-------------------+------+--------------------+--------------------+------------+-----------------+------------+
# |AE223RTPWMG62AWDZ...| B07J5KZY8N|2019-10-14 15:55:19|     4|More than I expected|I didn't have muc...|           0|             true|       false|
# |AE223YNB742YCE2HS...| B00AX3YNPC|2014-07-21 09:18:37|     5|          Five Stars|Works well and fi...|           0|             true|       false|
# |AE224HM2QAW5TTSDL...| B0001HYKBC|2004-10-12 14:19:20|     4|Really As Close a...|I found the Nivea...|          22|            false|       false|
# |AE225IKAL7QABBT2B...| B06XZJTCYW|2019-12-24 13:53:30|     1|                 Meh|I haven’t really ...|           0|             true|       false|
# |AE225P5MUY5NWM7QU...| B01H1I26N2|2017-08-27 23:30:25|     3|         Three Stars|Didn't seem to wo...|           0|            false|       false|
# |AE225THXPLSO5QQ3P...| B07RTZMBQC|2019-06-27 17:41:42|     4|Very beautiful sh...|I loved this shad...|           2|             true|        true|
# |AE225THXPLSO5QQ3P...| B07RVPC6X5|2019-06-27 17:39:04|     3|Beautiful color b...|I loved this shad...|           4|             true|        true|
# |AE227C3U2DDLOMLH7...| B086JVNM61|2020-07-26 14:57:05|     2|Tops pop open too...|Tops pop open way...|           0|             true|       false|
# |AE22BCXGNK7GV24HS...| B087P5DN6R|2020-10-09 14:21:04|     3|Wanted to love this.|I really wanted t...|           0|             true|       false|
# |AE22BJCLGXGMOFCGO...| B0171UQIUW|2016-02-11 00:01:40|     5|This is a life sa...|This is a life sa...|           0|             true|       false|
# +--------------------+-----------+-------------------+------+--------------------+--------------------+------------+-----------------+------------+
# only showing top 10 rows

# %%
# Load Meta Data
spark.conf.set("spark.sql.caseSensitive", "true")
df_meta = spark.read.json(data + "meta_All_Beauty.jsonl")

# %%
# Before Cleaning (Meta)
df_meta.printSchema()
df_meta.show(10)
# Out:
# root
#  |-- average_rating: double (nullable = true)
#  |-- bought_together: string (nullable = true)
#  |-- categories: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- description: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- details: struct (nullable = true)
#  |    |-- Action: string (nullable = true)
#  |    |-- Active Ingredients: string (nullable = true)
#  |    |-- Adjustable Length: string (nullable = true)
#  |    |-- Age Range (Description): string (nullable = true)
#  |    |-- Age Range Description: string (nullable = true)
#  |    |-- Alcohol Content: string (nullable = true)
#  |    |-- Allergen Information: string (nullable = true)
#  |    |-- Amperage: string (nullable = true)
#  |    |-- Antenna: string (nullable = true)
#  |    |-- Arch Type: string (nullable = true)
#  |    |-- Are Batteries Included: string (nullable = true)
#  |    |-- Assembly Required: string (nullable = true)
#  |    |-- Assembly Required No: string (nullable = true)
#  |    |-- Assembly Required Yes: string (nullable = true)
#  |    |-- Assembly required: string (nullable = true)
#  |    |-- Auto Part Position: string (nullable = true)
#  |    |-- Auto Shutoff: string (nullable = true)
#  |    |-- Back Style: string (nullable = true)
#  |    |-- Band Color: string (nullable = true)
#  |    |-- Band Length: string (nullable = true)
#  |    |-- Band Material Type: string (nullable = true)
#  |    |-- Band Size: string (nullable = true)
#  |    |-- Band Width: string (nullable = true)
#  |    |-- Base Type: string (nullable = true)
#  |    |-- Batteries: string (nullable = true)
#  |    |-- Batteries Included?: string (nullable = true)
#  |    |-- Batteries Required?: string (nullable = true)
#  |    |-- Batteries required: string (nullable = true)
#  |    |-- Battery Cell Composition: string (nullable = true)
#  |    |-- Battery Description: string (nullable = true)
#  |    |-- Battery Life: string (nullable = true)
#  |    |-- Binding: string (nullable = true)
#  |    |-- Blade Color: string (nullable = true)
#  |    |-- Blade Edge: string (nullable = true)
#  |    |-- Blade Length: string (nullable = true)
#  |    |-- Blade Material: string (nullable = true)
#  |    |-- Blade Shape: string (nullable = true)
#  |    |-- Blanket Form: string (nullable = true)
#  |    |-- Body Shape: string (nullable = true)
#  |    |-- Bottle Nipple Type: string (nullable = true)
#  |    |-- Bottle Type: string (nullable = true)
#  |    |-- Bowl Material: string (nullable = true)
#  |    |-- Brand: string (nullable = true)
#  |    |-- Brand Name: string (nullable = true)
#  |    |-- Breed Recommendation: string (nullable = true)
#  |    |-- Bristle Material: string (nullable = true)
#  |    |-- Bristle Type: string (nullable = true)
#  |    |-- Brush Length: string (nullable = true)
#  |    |-- Bulb Shape Size: string (nullable = true)
#  |    |-- CPSIA Cautionary Statement: string (nullable = true)
#  |    |-- Cable Feature: string (nullable = true)
#  |    |-- Cable Type: string (nullable = true)
#  |    |-- Camera Lens Description: string (nullable = true)
#  |    |-- Capacity: string (nullable = true)
#  |    |-- Care instructions: string (nullable = true)
#  |    |-- Cartoon Character: string (nullable = true)
#  |    |-- Caster Type: string (nullable = true)
#  |    |-- Center To Center Spacing: string (nullable = true)
#  |    |-- Chain Type: string (nullable = true)
#  |    |-- Charging Time: string (nullable = true)
#  |    |-- Chocolate Type: string (nullable = true)
#  |    |-- Clarity: string (nullable = true)
#  |    |-- Clasp Type: string (nullable = true)
#  |    |-- Closure Type: string (nullable = true)
#  |    |-- Collection Name: string (nullable = true)
#  |    |-- Color: string (nullable = true)
#  |    |-- Color Name: string (nullable = true)
#  |    |-- Compatibility Options: string (nullable = true)
#  |    |-- Compatible Devices: string (nullable = true)
#  |    |-- Compatible Material: string (nullable = true)
#  |    |-- Compatible Phone Models: string (nullable = true)
#  |    |-- Component Type: string (nullable = true)
#  |    |-- Configuration: string (nullable = true)
#  |    |-- Connectivity Technology: string (nullable = true)
#  |    |-- Connectivity technologies: string (nullable = true)
#  |    |-- Connector Gender: string (nullable = true)
#  |    |-- Connector Type: string (nullable = true)
#  |    |-- Construction Type: string (nullable = true)
#  |    |-- Contact Material: string (nullable = true)
#  |    |-- Contains Liquid Contents: string (nullable = true)
#  |    |-- Contributor: string (nullable = true)
#  |    |-- Control Method: string (nullable = true)
#  |    |-- Controller Type: string (nullable = true)
#  |    |-- Corner Style: string (nullable = true)
#  |    |-- Country of Origin: string (nullable = true)
#  |    |-- Country/Region Of Origin: string (nullable = true)
#  |    |-- Cover Material: string (nullable = true)
#  |    |-- Coverage: string (nullable = true)
#  |    |-- Cuisine: string (nullable = true)
#  |    |-- Cut Type: string (nullable = true)
#  |    |-- Data Transfer Rate: string (nullable = true)
#  |    |-- Date First Available: string (nullable = true)
#  |    |-- Dental Floss Type: string (nullable = true)
#  |    |-- Department: string (nullable = true)
#  |    |-- Desk design: string (nullable = true)
#  |    |-- Diet Type: string (nullable = true)
#  |    |-- Display Type: string (nullable = true)
#  |    |-- Display resolution: string (nullable = true)
#  |    |-- Domestic Shipping: string (nullable = true)
#  |    |-- Dosage Form: string (nullable = true)
#  |    |-- Duration: string (nullable = true)
#  |    |-- Edition Number: string (nullable = true)
#  |    |-- Educational Objective: string (nullable = true)
#  |    |-- Electric fan design: string (nullable = true)
#  |    |-- Embellishment: string (nullable = true)
#  |    |-- Expected Blooming Period: string (nullable = true)
#  |    |-- Extended Length: string (nullable = true)
#  |    |-- Extension Length: string (nullable = true)
#  |    |-- Exterior Finish: string (nullable = true)
#  |    |-- External Testing Certification: string (nullable = true)
#  |    |-- Eyelid Color Type: string (nullable = true)
#  |    |-- Fabric Type: string (nullable = true)
#  |    |-- Fastener Material: string (nullable = true)
#  |    |-- Fastener Type: string (nullable = true)
#  |    |-- Ferrule Material: string (nullable = true)
#  |    |-- Fill Material: string (nullable = true)
#  |    |-- Filter Class: string (nullable = true)
#  |    |-- Filter Type: string (nullable = true)
#  |    |-- Finish: string (nullable = true)
#  |    |-- Finish Type: string (nullable = true)
#  |    |-- Finish types: string (nullable = true)
#  |    |-- Fishing Technique: string (nullable = true)
#  |    |-- Fit Type: string (nullable = true)
#  |    |-- Fit Type Universal Fit: string (nullable = true)
#  |    |-- Flavor: string (nullable = true)
#  |    |-- Form Factor: string (nullable = true)
#  |    |-- Format: string (nullable = true)
#  |    |-- Formulation Type: string (nullable = true)
#  |    |-- Fragrance Concentration: string (nullable = true)
#  |    |-- Frame Material: string (nullable = true)
#  |    |-- Frame Material Aluminum, Nylon: string (nullable = true)
#  |    |-- Frame Type: string (nullable = true)
#  |    |-- Full Cure Time: string (nullable = true)
#  |    |-- Furniture Finish: string (nullable = true)
#  |    |-- Genre: string (nullable = true)
#  |    |-- Grade Rating: string (nullable = true)
#  |    |-- Grit Material: string (nullable = true)
#  |    |-- Grit Number: string (nullable = true)
#  |    |-- Grit Type: string (nullable = true)
#  |    |-- Hair Type: string (nullable = true)
#  |    |-- Hand Orientation: string (nullable = true)
#  |    |-- Handle Material: string (nullable = true)
#  |    |-- Handle Type: string (nullable = true)
#  |    |-- Hardware Platform: string (nullable = true)
#  |    |-- Has Nonstick Coating: string (nullable = true)
#  |    |-- Head Material: string (nullable = true)
#  |    |-- Head Type: string (nullable = true)
#  |    |-- Headphones Jack: string (nullable = true)
#  |    |-- Heat Output: string (nullable = true)
#  |    |-- Heater Surface Material: string (nullable = true)
#  |    |-- Honey Type: string (nullable = true)
#  |    |-- Human Interface Input: string (nullable = true)
#  |    |-- Image Stabilization: string (nullable = true)
#  |    |-- Import: string (nullable = true)
#  |    |-- Import Designation: string (nullable = true)
#  |    |-- Included Components: string (nullable = true)
#  |    |-- Incontinence Protector Type: string (nullable = true)
#  |    |-- Indoor/Outdoor Usage: string (nullable = true)
#  |    |-- Ink Color: string (nullable = true)
#  |    |-- Inner Material: string (nullable = true)
#  |    |-- Input Voltage: string (nullable = true)
#  |    |-- Installation Type: string (nullable = true)
#  |    |-- Installation Type Adhesive: string (nullable = true)
#  |    |-- Installation Type Adhesión estática: string (nullable = true)
#  |    |-- Installation Type Peel: string (nullable = true)
#  |    |-- Installation Type Self-Adhesive: string (nullable = true)
#  |    |-- Installation Type Stick: string (nullable = true)
#  |    |-- Installation Type Water transfer: string (nullable = true)
#  |    |-- Installation Type water transfer: string (nullable = true)
#  |    |-- Instrument Key: string (nullable = true)
#  |    |-- International Protection Rating: string (nullable = true)
#  |    |-- International Shipping: string (nullable = true)
#  |    |-- Is Autographed: string (nullable = true)
#  |    |-- Is Cordless?: string (nullable = true)
#  |    |-- Is Discontinued By Manufacturer: string (nullable = true)
#  |    |-- Is Dishwasher Safe: string (nullable = true)
#  |    |-- Is Electric: string (nullable = true)
#  |    |-- Is Foldable: string (nullable = true)
#  |    |-- Is Microwaveable: string (nullable = true)
#  |    |-- Is Oven Safe: string (nullable = true)
#  |    |-- Is Product Expirable: string (nullable = true)
#  |    |-- Is Stain Resistant: string (nullable = true)
#  |    |-- Is Waterproof: string (nullable = true)
#  |    |-- Is framed?: string (nullable = true)
#  |    |-- Item Diameter: string (nullable = true)
#  |    |-- Item Dimensions  LxWxH: string (nullable = true)
#  |    |-- Item Dimensions LxWxH: string (nullable = true)
#  |    |-- Item Firmness Description: string (nullable = true)
#  |    |-- Item Form: string (nullable = true)
#  |    |-- Item Hardness: string (nullable = true)
#  |    |-- Item Length: string (nullable = true)
#  |    |-- Item Package Dimensions L x W x H: string (nullable = true)
#  |    |-- Item Package Quantity: string (nullable = true)
#  |    |-- Item Volume: string (nullable = true)
#  |    |-- Item Weight: string (nullable = true)
#  |    |-- Item Weight 1 Kilograms: string (nullable = true)
#  |    |-- Item Weight 176.37 Pounds: string (nullable = true)
#  |    |-- Item model number: string (nullable = true)
#  |    |-- Keyboard Description: string (nullable = true)
#  |    |-- Lamp Type: string (nullable = true)
#  |    |-- Language: string (nullable = true)
#  |    |-- League: string (nullable = true)
#  |    |-- Lens Curvature Description: string (nullable = true)
#  |    |-- Lens Material: string (nullable = true)
#  |    |-- Lens Type: string (nullable = true)
#  |    |-- Lid Material: string (nullable = true)
#  |    |-- Light Color: string (nullable = true)
#  |    |-- Light Source Type: string (nullable = true)
#  |    |-- Light Type: string (nullable = true)
#  |    |-- Lining Description: string (nullable = true)
#  |    |-- Liquid Contents Description: string (nullable = true)
#  |    |-- Liquid Volume: string (nullable = true)
#  |    |-- Load Capacity: string (nullable = true)
#  |    |-- Magnification Strength: string (nullable = true)
#  |    |-- Main Power Connector Type: string (nullable = true)
#  |    |-- Manufacturer: string (nullable = true)
#  |    |-- Manufacturer Minimum Age (MONTHS): string (nullable = true)
#  |    |-- Manufacturer Part Number: string (nullable = true)
#  |    |-- Manufacturer recommended age: string (nullable = true)
#  |    |-- Material: string (nullable = true)
#  |    |-- Material Acrylic: string (nullable = true)
#  |    |-- Material Composition: string (nullable = true)
#  |    |-- Material Feature: string (nullable = true)
#  |    |-- Material Glass: string (nullable = true)
#  |    |-- Material Leather: string (nullable = true)
#  |    |-- Material Leather, Polyvinyl Chloride: string (nullable = true)
#  |    |-- Material Melamine: string (nullable = true)
#  |    |-- Material Nail: string (nullable = true)
#  |    |-- Material Nail art: string (nullable = true)
#  |    |-- Material Nylon, Aluminum, Leather: string (nullable = true)
#  |    |-- Material PVC: string (nullable = true)
#  |    |-- Material Paper: string (nullable = true)
#  |    |-- Material Paper, Metal: string (nullable = true)
#  |    |-- Material Paper, Plastic: string (nullable = true)
#  |    |-- Material Pec: string (nullable = true)
#  |    |-- Material Plastic: string (nullable = true)
#  |    |-- Material Polyethylene: string (nullable = true)
#  |    |-- Material Polyurethane: string (nullable = true)
#  |    |-- Material Resin: string (nullable = true)
#  |    |-- Material Silicone: string (nullable = true)
#  |    |-- Material Silk: string (nullable = true)
#  |    |-- Material Stainless Steel: string (nullable = true)
#  |    |-- Material Type: string (nullable = true)
#  |    |-- Material Type Free: string (nullable = true)
#  |    |-- Material Vinyl: string (nullable = true)
#  |    |-- Material Wood: string (nullable = true)
#  |    |-- Max Temperature Setting: string (nullable = true)
#  |    |-- Maximum Height Recommendation: string (nullable = true)
#  |    |-- Maximum Range: string (nullable = true)
#  |    |-- Maximum Rotational Speed: string (nullable = true)
#  |    |-- Maximum Weight Recommendation: string (nullable = true)
#  |    |-- Memory Storage Capacity: string (nullable = true)
#  |    |-- Metal Stamp: string (nullable = true)
#  |    |-- Metal Type: string (nullable = true)
#  |    |-- Microphone Form Factor: string (nullable = true)
#  |    |-- Model Info: string (nullable = true)
#  |    |-- Model Name: string (nullable = true)
#  |    |-- Moisture Needs: string (nullable = true)
#  |    |-- Mounting Type: string (nullable = true)
#  |    |-- Mounting Type Desktop: string (nullable = true)
#  |    |-- Mounting Type Free Standing: string (nullable = true)
#  |    |-- Mounting Type Freestanding: string (nullable = true)
#  |    |-- Mounting Type On Your Dressing Table,Bathroom: string (nullable = true)
#  |    |-- Mounting Type Tabletop Mount: string (nullable = true)
#  |    |-- Mounting Type Wall Mount: string (nullable = true)
#  |    |-- Multiline Operation: string (nullable = true)
#  |    |-- National Stock Number: string (nullable = true)
#  |    |-- Net Content Volume: string (nullable = true)
#  |    |-- Net Content Weight: string (nullable = true)
#  |    |-- Nominal Wall Thickness: string (nullable = true)
#  |    |-- Number Of Doors: string (nullable = true)
#  |    |-- Number Of Items: string (nullable = true)
#  |    |-- Number Of Pieces: string (nullable = true)
#  |    |-- Number Of Pockets: string (nullable = true)
#  |    |-- Number of Batteries: string (nullable = true)
#  |    |-- Number of Blades: string (nullable = true)
#  |    |-- Number of Buttons: string (nullable = true)
#  |    |-- Number of Channels: string (nullable = true)
#  |    |-- Number of Compartments: string (nullable = true)
#  |    |-- Number of Compartments 3: string (nullable = true)
#  |    |-- Number of Compartments 8: string (nullable = true)
#  |    |-- Number of Doors: string (nullable = true)
#  |    |-- Number of Drawers: string (nullable = true)
#  |    |-- Number of Handles: string (nullable = true)
#  |    |-- Number of Items: string (nullable = true)
#  |    |-- Number of Keys: string (nullable = true)
#  |    |-- Number of Labels: string (nullable = true)
#  |    |-- Number of Light Sources: string (nullable = true)
#  |    |-- Number of Pieces: string (nullable = true)
#  |    |-- Number of Players: string (nullable = true)
#  |    |-- Number of Ports: string (nullable = true)
#  |    |-- Number of Sets: string (nullable = true)
#  |    |-- Number of Shelves: string (nullable = true)
#  |    |-- Number of Speeds: string (nullable = true)
#  |    |-- Number of Wheels: string (nullable = true)
#  |    |-- Number of pieces: string (nullable = true)
#  |    |-- Number of settings: string (nullable = true)
#  |    |-- Occasion: string (nullable = true)
#  |    |-- Occupancy: string (nullable = true)
#  |    |-- Occupant Capacity: string (nullable = true)
#  |    |-- Opacity: string (nullable = true)
#  |    |-- Opening Mechanism: string (nullable = true)
#  |    |-- Operating System: string (nullable = true)
#  |    |-- Operating Time: string (nullable = true)
#  |    |-- Operation Mode: string (nullable = true)
#  |    |-- Optical Zoom: string (nullable = true)
#  |    |-- Orientation: string (nullable = true)
#  |    |-- Other display features: string (nullable = true)
#  |    |-- Our Recommended age: string (nullable = true)
#  |    |-- Outer Material: string (nullable = true)
#  |    |-- Output Current: string (nullable = true)
#  |    |-- Output Voltage: string (nullable = true)
#  |    |-- Package Dimensions: string (nullable = true)
#  |    |-- Package Information: string (nullable = true)
#  |    |-- Package Type: string (nullable = true)
#  |    |-- Package Weight: string (nullable = true)
#  |    |-- Page Yield: string (nullable = true)
#  |    |-- Pages: string (nullable = true)
#  |    |-- Paint Type: string (nullable = true)
#  |    |-- Paper Finish: string (nullable = true)
#  |    |-- Part Number: string (nullable = true)
#  |    |-- Pattern: string (nullable = true)
#  |    |-- Percentage assay: string (nullable = true)
#  |    |-- Pile Height: string (nullable = true)
#  |    |-- Pillow Type: string (nullable = true)
#  |    |-- Plant or Animal Product Type: string (nullable = true)
#  |    |-- Ply Rating: string (nullable = true)
#  |    |-- Point Type: string (nullable = true)
#  |    |-- Power Source: string (nullable = true)
#  |    |-- Primary Supplement Type: string (nullable = true)
#  |    |-- Print media: string (nullable = true)
#  |    |-- Printer Output: string (nullable = true)
#  |    |-- Printing Technology: string (nullable = true)
#  |    |-- Produce sold as: string (nullable = true)
#  |    |-- Product Benefits: string (nullable = true)
#  |    |-- Product Care Instructions: string (nullable = true)
#  |    |-- Product Dimensions: string (nullable = true)
#  |    |-- Product Grade: string (nullable = true)
#  |    |-- Readout Accuracy: string (nullable = true)
#  |    |-- Real Angle of View: string (nullable = true)
#  |    |-- Recommended Uses For Product: string (nullable = true)
#  |    |-- Reminder: string (nullable = true)
#  |    |-- Reusability: string (nullable = true)
#  |    |-- Rim Size: string (nullable = true)
#  |    |-- Room Type: string (nullable = true)
#  |    |-- Ruling Type: string (nullable = true)
#  |    |-- Runtime: string (nullable = true)
#  |    |-- Scanner Type: string (nullable = true)
#  |    |-- Scent: string (nullable = true)
#  |    |-- Screen Size: string (nullable = true)
#  |    |-- Screen Surface Description: string (nullable = true)
#  |    |-- Seasons: string (nullable = true)
#  |    |-- Seat Height: string (nullable = true)
#  |    |-- Seat Material Type: string (nullable = true)
#  |    |-- Series Number: string (nullable = true)
#  |    |-- Servings per Container: string (nullable = true)
#  |    |-- Shade Material: string (nullable = true)
#  |    |-- Shaft Material: string (nullable = true)
#  |    |-- Shank Type: string (nullable = true)
#  |    |-- Shape: string (nullable = true)
#  |    |-- Shape Heart: string (nullable = true)
#  |    |-- Shape Heart, Flower: string (nullable = true)
#  |    |-- Shape Irregular: string (nullable = true)
#  |    |-- Shape Oblong: string (nullable = true)
#  |    |-- Shape Rectangular: string (nullable = true)
#  |    |-- Shape Round: string (nullable = true)
#  |    |-- Shape Triangular: string (nullable = true)
#  |    |-- Sheet Count: string (nullable = true)
#  |    |-- Shell Type: string (nullable = true)
#  |    |-- Shelves: string (nullable = true)
#  |    |-- Size: string (nullable = true)
#  |    |-- Skill Level: string (nullable = true)
#  |    |-- Skin Tone: string (nullable = true)
#  |    |-- Skin Type: string (nullable = true)
#  |    |-- Soil Type: string (nullable = true)
#  |    |-- Sound Level: string (nullable = true)
#  |    |-- Speaker Type: string (nullable = true)
#  |    |-- Special Feature: string (nullable = true)
#  |    |-- Special Features: string (nullable = true)
#  |    |-- Special Ingredients: string (nullable = true)
#  |    |-- Special features: string (nullable = true)
#  |    |-- Specialty: string (nullable = true)
#  |    |-- Specific Uses For Product: string (nullable = true)
#  |    |-- Specification Met: string (nullable = true)
#  |    |-- Specifications: string (nullable = true)
#  |    |-- Sport: string (nullable = true)
#  |    |-- Sport Type: string (nullable = true)
#  |    |-- Sterility Rating: string (nullable = true)
#  |    |-- Stone Shape: string (nullable = true)
#  |    |-- Strap Type: string (nullable = true)
#  |    |-- Style: string (nullable = true)
#  |    |-- Style French: string (nullable = true)
#  |    |-- Sub Brand: string (nullable = true)
#  |    |-- Subwoofer Diameter: string (nullable = true)
#  |    |-- Suitable Hair Color: string (nullable = true)
#  |    |-- Sun Protection: string (nullable = true)
#  |    |-- Sun Protection Factor: string (nullable = true)
#  |    |-- Sunlight Exposure: string (nullable = true)
#  |    |-- Supported Application: string (nullable = true)
#  |    |-- Supported Standards: string (nullable = true)
#  |    |-- Surface Recommendation: string (nullable = true)
#  |    |-- Surface Recommendation Aluminum: string (nullable = true)
#  |    |-- Surface Recommendation Ceramic: string (nullable = true)
#  |    |-- Surface Recommendation Floor: string (nullable = true)
#  |    |-- Surface Recommendation Foil: string (nullable = true)
#  |    |-- Surface Recommendation Furniture: string (nullable = true)
#  |    |-- Surface Recommendation Glass: string (nullable = true)
#  |    |-- Surface Recommendation Metal: string (nullable = true)
#  |    |-- Surface Recommendation Nail: string (nullable = true)
#  |    |-- Surface Recommendation Nails: string (nullable = true)
#  |    |-- Surface Recommendation Paper with Sticker: string (nullable = true)
#  |    |-- Surface Recommendation Plastic: string (nullable = true)
#  |    |-- Surface Recommendation Wall: string (nullable = true)
#  |    |-- Surface Recommendation Window: string (nullable = true)
#  |    |-- Surface Recommendation nail: string (nullable = true)
#  |    |-- Surface Recommendation nails: string (nullable = true)
#  |    |-- Surface Recommendation wall: string (nullable = true)
#  |    |-- Switch Type: string (nullable = true)
#  |    |-- TV Size: string (nullable = true)
#  |    |-- Table design: string (nullable = true)
#  |    |-- Tank Volume: string (nullable = true)
#  |    |-- Target Audience: string (nullable = true)
#  |    |-- Target Species: string (nullable = true)
#  |    |-- Target gender: string (nullable = true)
#  |    |-- Tea Variety: string (nullable = true)
#  |    |-- Team Name: string (nullable = true)
#  |    |-- Terminal: string (nullable = true)
#  |    |-- Theme: string (nullable = true)
#  |    |-- Thread Type: string (nullable = true)
#  |    |-- Tool Flute Type: string (nullable = true)
#  |    |-- Top Material Type: string (nullable = true)
#  |    |-- Top Style: string (nullable = true)
#  |    |-- Total Eaches: string (nullable = true)
#  |    |-- Total USB Ports: string (nullable = true)
#  |    |-- Towel form type: string (nullable = true)
#  |    |-- Type: string (nullable = true)
#  |    |-- UPC: string (nullable = true)
#  |    |-- USDA Hardiness Zone: string (nullable = true)
#  |    |-- Ultraviolet Light Protection: string (nullable = true)
#  |    |-- Unit Count: string (nullable = true)
#  |    |-- Units: string (nullable = true)
#  |    |-- Usage: string (nullable = true)
#  |    |-- Use for: string (nullable = true)
#  |    |-- Valve Type: string (nullable = true)
#  |    |-- Variety: string (nullable = true)
#  |    |-- Vehicle Service Type: string (nullable = true)
#  |    |-- Ventilation Type: string (nullable = true)
#  |    |-- Voltage: string (nullable = true)
#  |    |-- Volume: string (nullable = true)
#  |    |-- Waist (cm): string (nullable = true)
#  |    |-- Wall Art Form: string (nullable = true)
#  |    |-- Warranty Description: string (nullable = true)
#  |    |-- Water Resistance Level: string (nullable = true)
#  |    |-- Wattage: string (nullable = true)
#  |    |-- Weave Type: string (nullable = true)
#  |    |-- Weight: string (nullable = true)
#  |    |-- Weight Limit: string (nullable = true)
#  |    |-- Whats in the box: string (nullable = true)
#  |    |-- Wheel Size: string (nullable = true)
#  |    |-- Whistling: string (nullable = true)
#  |    |-- Wireless Communication Standard: string (nullable = true)
#  |    |-- Wireless Communication Technology: string (nullable = true)
#  |    |-- With Lid: string (nullable = true)
#  |    |-- Year: string (nullable = true)
#  |-- features: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- images: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- hi_res: string (nullable = true)
#  |    |    |-- large: string (nullable = true)
#  |    |    |-- thumb: string (nullable = true)
#  |    |    |-- variant: string (nullable = true)
#  |-- main_category: string (nullable = true)
#  |-- parent_asin: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- rating_number: long (nullable = true)
#  |-- store: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- videos: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- user_id: string (nullable = true)
#
# +--------------+---------------+----------+--------------------+--------------------+--------------------+--------------------+-------------+-----------+-----+-------------+--------------------+--------------------+------+
# |average_rating|bought_together|categories|         description|             details|            features|              images|main_category|parent_asin|price|rating_number|               store|               title|videos|
# +--------------+---------------+----------+--------------------+--------------------+--------------------+--------------------+-------------+-----------+-----+-------------+--------------------+--------------------+------+
# |           4.8|           NULL|        []|                  []|{NULL, NULL, NULL...|                  []|[{NULL, https://m...|   All Beauty| B01CUPMQZE| NULL|           10|     Howard Products|Howard LC0008 Lea...|    []|
# |           4.5|           NULL|        []|                  []|{NULL, NULL, NULL...|                  []|[{https://m.media...|   All Beauty| B076WQZGPM| NULL|            3|              Yes To|Yes to Tomatoes D...|    []|
# |           4.4|           NULL|        []|                  []|{NULL, NULL, NULL...|                  []|[{NULL, https://m...|   All Beauty| B000B658RI| NULL|           26|Levine Health Pro...|Eye Patch Black A...|    []|
# |           3.1|           NULL|        []|                  []|{NULL, NULL, NULL...|                  []|[{https://m.media...|   All Beauty| B088FKY3VD| NULL|          102|            Cherioll|Tattoo Eyebrow St...|    []|
# |           4.3|           NULL|        []|[The Precision Pl...|{NULL, NULL, NULL...|[Material: 304 St...|[{NULL, https://m...|   All Beauty| B07NGFDN6G| NULL|            7|           Precision|Precision Plunger...|    []|
# |           3.7|           NULL|        []|[Description, The...|{NULL, NULL, NULL...|[The false toenai...|[{https://m.media...|   All Beauty| B07G9GWFSM| 6.99|           35|             Lurrose|Lurrose 100Pcs Fu...|    []|
# |           4.1|           NULL|        []|                  []|{NULL, NULL, NULL...|                  []|[{https://m.media...|   All Beauty| B08XZ97HFY| NULL|           50|            Edoneery|Stain Bonnet For ...|    []|
# |           3.8|           NULL|        []|                  []|{NULL, NULL, NULL...|                  []|[{https://m.media...|   All Beauty| B08DNQTTQK| NULL|           32|              Maitys|50 Pieces False E...|    []|
# |           3.7|           NULL|        []|[Edt spray 3 oz d...|{NULL, NULL, NULL...|[Extatic Balmain ...|[{https://m.media...|   All Beauty| B01ERJEGS6|86.95|            2|             Balmain|Gold extatic Musk...|    []|
# |           4.3|           NULL|        []|                  []|{NULL, NULL, NULL...|                  []|[{https://m.media...|   All Beauty| B08P7LXKP7| NULL|           66|              Geyoga|4 Pieces Satin Bo...|    []|
# +--------------+---------------+----------+--------------------+--------------------+--------------------+--------------------+-------------+-----------+-----+-------------+--------------------+--------------------+------+
# only showing top 10 rows

# %%
# Meta dataset cleaning
from pyspark.sql.functions import transform, array_join, split, concat_ws

## New Column "image_exist" to flag whether review contains image or not
df_meta = df_meta.withColumn(
    "product_video",
    (coalesce(size(col("videos")), lit(0)) > 0)
)

## New Column "image_exist" to flag whether review contains image or not
df_meta = df_meta.withColumn(
    "product_image",
    (coalesce(size(col("images")), lit(0)) > 0)
)

## Drop images / videos
df_meta = df_meta.drop("images", "videos", "details")

## String text clean(trim) - clean multiple spaces & lowercase (store)
df_meta = (df_meta
    .withColumn("features",
        transform(
            col("features"),
            lambda x: (trim(regexp_replace(x, r"\s+", " ")))
        )
    )
    .withColumn("description",
        transform(
            col("description"),
            lambda x: trim(regexp_replace(x, r"\s+", " "))
        )
    )
)

df_meta = (df_meta
           .withColumn("product_name",  trim(regexp_replace(col("title"),  r"\s+", " ")))
           .withColumn("store", lower(trim(regexp_replace(col("store"),  r"\s+", " "))))
)

df_meta = df_meta.drop("title")

## Number of features
df_meta = df_meta.withColumn(
    "feature_count",
    coalesce(size(col("features")), lit(0))
)

## Description word count
df_meta = df_meta.withColumn(
    "description_word_count",
    when(col("description").isNull() | (size(col("description")) == 0), lit(0))
    .otherwise(
        size(
            split(
                trim(
                    regexp_replace(concat_ws(" ", col("description")), r"\s+", " ")
                ),
                r"\s+"
            )
        )
    )
)

## Column order reconstruct
meta_final_cols = [
    "parent_asin",
    "product_name",
    "main_category",
    "categories",
    "price",
    "features",
    "feature_count",
    "description",
    "description_word_count",
    "average_rating",
    "rating_number",
    "store",
    "product_image",
    "product_video"
]

df_meta = df_meta.select(*meta_final_cols)

# %%
# After Cleaning (Meta)
df_meta.printSchema()
df_meta.show(10)
# Out:
# root
#  |-- parent_asin: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- main_category: string (nullable = true)
#  |-- categories: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- price: double (nullable = true)
#  |-- features: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- feature_count: integer (nullable = false)
#  |-- description: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- description_word_count: integer (nullable = false)
#  |-- average_rating: double (nullable = true)
#  |-- rating_number: long (nullable = true)
#  |-- store: string (nullable = true)
#  |-- product_image: boolean (nullable = false)
#  |-- product_video: boolean (nullable = false)
#
# +-----------+--------------------+-------------+----------+-----+--------------------+-------------+--------------------+----------------------+--------------+-------------+--------------------+-------------+-------------+
# |parent_asin|        product_name|main_category|categories|price|            features|feature_count|         description|description_word_count|average_rating|rating_number|               store|product_image|product_video|
# +-----------+--------------------+-------------+----------+-----+--------------------+-------------+--------------------+----------------------+--------------+-------------+--------------------+-------------+-------------+
# | B01CUPMQZE|Howard LC0008 Lea...|   All Beauty|        []| NULL|                  []|            0|                  []|                     0|           4.8|           10|     howard products|         true|        false|
# | B076WQZGPM|Yes to Tomatoes D...|   All Beauty|        []| NULL|                  []|            0|                  []|                     0|           4.5|            3|              yes to|         true|        false|
# | B000B658RI|Eye Patch Black A...|   All Beauty|        []| NULL|                  []|            0|                  []|                     0|           4.4|           26|levine health pro...|         true|        false|
# | B088FKY3VD|Tattoo Eyebrow St...|   All Beauty|        []| NULL|                  []|            0|                  []|                     0|           3.1|          102|            cherioll|         true|        false|
# | B07NGFDN6G|Precision Plunger...|   All Beauty|        []| NULL|[Material: 304 St...|            5|[The Precision Pl...|                    68|           4.3|            7|           precision|         true|        false|
# | B07G9GWFSM|Lurrose 100Pcs Fu...|   All Beauty|        []| 6.99|[The false toenai...|            5|[Description, The...|                    92|           3.7|           35|             lurrose|         true|        false|
# | B08XZ97HFY|Stain Bonnet For ...|   All Beauty|        []| NULL|                  []|            0|                  []|                     0|           4.1|           50|            edoneery|         true|        false|
# | B08DNQTTQK|50 Pieces False E...|   All Beauty|        []| NULL|                  []|            0|                  []|                     0|           3.8|           32|              maitys|         true|        false|
# | B01ERJEGS6|Gold extatic Musk...|   All Beauty|        []|86.95|[Extatic Balmain ...|            1|[Edt spray 3 oz d...|                     7|           3.7|            2|             balmain|         true|        false|
# | B08P7LXKP7|4 Pieces Satin Bo...|   All Beauty|        []| NULL|                  []|            0|                  []|                     0|           4.3|           66|              geyoga|         true|        false|
# +-----------+--------------------+-------------+----------+-----+--------------------+-------------+--------------------+----------------------+--------------+-------------+--------------------+-------------+-------------+
# only showing top 10 rows

# %%
# Left join two datasets (Review & Meta)
from pyspark.sql.functions import col

df_joined = df.join(
    df_meta,                    # the metadata table
    on="parent_asin",           # join key
    how="left"                  # keep all rows from df
)

df_joined.show(3)
# Out:
# [Stage 30:>                                                         (0 + 1) / 1]
# +-----------+--------------------+-------------------+------+--------------------+--------------------+------------+-----------------+------------+--------------------+-------------+----------+------+--------------------+-------------+--------------------+----------------------+--------------+-------------+-------+-------------+-------------+
# |parent_asin|             user_id|          timestamp|rating|        review_title|         review_text|helpful_vote|verified_purchase|review_image|        product_name|main_category|categories| price|            features|feature_count|         description|description_word_count|average_rating|rating_number|  store|product_image|product_video|
# +-----------+--------------------+-------------------+------+--------------------+--------------------+------------+-----------------+------------+--------------------+-------------+----------+------+--------------------+-------------+--------------------+----------------------+--------------+-------------+-------+-------------+-------------+
# | B07J5KZY8N|AE223RTPWMG62AWDZ...|2019-10-14 15:55:19|     4|More than I expected|I didn't have muc...|           0|             true|       false|Brazilian Virgin ...|   All Beauty|        []|  NULL|                  []|            0|                  []|                     0|           3.3|            5|   NULL|         true|        false|
# | B00AX3YNPC|AE223YNB742YCE2HS...|2014-07-21 09:18:37|     5|          Five Stars|Works well and fi...|           0|             true|       false|Braun Silk Epil F...|   All Beauty|        []|159.95|[Wet & Dry - Can ...|            5|[View larger, Bra...|                   990|           3.9|          445|  braun|         true|        false|
# | B0001HYKBC|AE224HM2QAW5TTSDL...|2004-10-12 14:19:20|     4|Really As Close a...|I found the Nivea...|          22|            false|       false|Philips Norelco 7...|   All Beauty|        []|  NULL|[Rechargeable, co...|            5|[Product Descript...|                   579|           3.1|           90|philips|         true|        false|
# +-----------+--------------------+-------------------+------+--------------------+--------------------+------------+-----------------+------------+--------------------+-------------+----------+------+--------------------+-------------+--------------------+----------------------+--------------+-------------+-------+-------------+-------------+
# only showing top 3 rows
